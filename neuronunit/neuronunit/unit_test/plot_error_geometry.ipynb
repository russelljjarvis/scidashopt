# %%
from neuronunit.models.reduced import ReducedModel
from neuronunit.optimization.model_parameters import model_params, path_params
from neuronunit.optimization import model_parameters as modelp
mp = modelp.model_params
import pdb
from neuronunit.optimization.data_transport_container import DataTC
dtc = DataTC()
from neuronunit.tests import np, pq, cap, VmTest, scores, AMPL, DELAY, DURATION
from neuronunit.models.backends import pyNN
try:
    import lazyarray
    import mpi4py
except:
    # !pip install lazyarray
    # !pip install mpi4py
    import lazyarray
    
    
import matplotlib.pyplot as plt
def plot(vm,plt):
    #vm = model.get_membrane_potential()
    times = vm.times
    #if hasattr(vm,'trace'):
    #   vm = vmpy.as_array()
    plt.plot(times,vm)
    plt.xlabel('ms')
    plt.ylabel('mV')
    #plt
    return plt

import pickle,os
from neuronunit.optimization import get_neab
electro_path = str(os.getcwd())+'/pipe_tests.p'
print(os.getcwd())
assert os.path.isfile(electro_path) == True
with open(electro_path,'rb') as f:
    electro_tests = pickle.load(f)

electro_tests = get_neab.replace_zero_std(electro_tests)
electro_tests = get_neab.substitute_parallel_for_serial(electro_tests)
tests, observation = electro_tests[0]

from neuronunit.optimization import model_parameters as modelp
# Out:
# sytactic error in OTHERBackend
# {'': <class 'neuronunit.models.backends.base.Backend'>, 'jNeuroML': <class 'neuronunit.models.backends.jNeuroML.jNeuroMLBackend'>, 'NEURON': <class 'neuronunit.models.backends.neuron.NEURONBackend'>, 'pyNN': <class 'neuronunit.models.backends.pyNN.pyNNBackend'>}
# <class 'neuronunit.models.backends.pyNN.pyNNBackend'>
# OrderedDict([('C', array([ 0.002  ,  0.00425,  0.0065 ,  0.00875,  0.011  ,  0.01325,
#         0.0155 ,  0.01775,  0.02   ])), ('k', array([  2.50000000e-05,   4.18750000e-05,   5.87500000e-05,
#          7.56250000e-05,   9.25000000e-05,   1.09375000e-04,
#          1.26250000e-04,   1.43125000e-04,   1.60000000e-04])), ('vr', array([-75. , -72.5, -70. , -67.5, -65. , -62.5, -60. , -57.5, -55. ])), ('vt', array([-50.  , -48.75, -47.5 , -46.25, -45.  , -43.75, -42.5 , -41.25, -40.  ])), ('vpeak', array([  0.  ,   6.25,  12.5 ,  18.75,  25.  ,  31.25,  37.5 ,  43.75,  50.  ])), ('a', array([  1.00000000e-06,   3.37500000e-06,   5.75000000e-06,
#          8.12500000e-06,   1.05000000e-05,   1.28750000e-05,
#          1.52500000e-05,   1.76250000e-05,   2.00000000e-05])), ('b', array([ -2.00000000e-04,   1.25000000e-05,   2.25000000e-04,
#          4.37500000e-04,   6.50000000e-04,   8.62500000e-04,
#          1.07500000e-03,   1.28750000e-03,   1.50000000e-03])), ('c', array([-60. , -57.5, -55. , -52.5, -50. , -47.5, -45. , -42.5, -40. ])), ('d', array([-0.0055   , -0.0029375, -0.000375 ,  0.0021875,  0.00475  ,
#         0.0073125,  0.009875 ,  0.0124375,  0.015    ]))])
# /home/jovyan/neuronunit/neuronunit/unit_test

# %%
model = ReducedModel(path_params['model_path'],name = str('regular_spiking'),backend =('NEURON',{'DTC':dtc}))

params = {'injected_square_current':
            {'amplitude': 11.0*pq.pA, 'delay':DELAY, 'duration':DURATION}}

model.inject_square_current(params)
n_spikes = model.get_spike_count()
vmrs2 = model.get_membrane_potential()
print(n_spikes)
# Out:
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=0.0007 vr=-60 vt=-40 vpeak=35 a=0.03 b=-0.002 c=-50 d=0.1 C=0.0001}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.011}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=0.0007 vr=-60 vt=-40 vpeak=35 a=0.03 b=-0.002 c=-50 d=0.1 C=0.0001}
# 	insert RS_Iext { weight=1 delay=0 duration=300 amplitude=0.011}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=0.0007 vr=-60 vt=-40 vpeak=35 a=0.03 b=-0.002 c=-50 d=0.1 C=0.0001}
# 	insert RS_Iext { weight=1 delay=100 duration=300 amplitude=0.011}
# }
# 0

# %% [markdown]
# # regular spiking cell (RS)

# %%
attrs = {}
attrs['c'] = -50
attrs['vr'] = -60
attrs['vt'] = -40
attrs['vpeak'] = 35


attrs['C'] = 100E-4
attrs['k'] = 0.7E-4
attrs['a'] = 0.03E-4
attrs['b'] = -2E-4
attrs['d'] = 100E-4



DELAY = 100 
DURATION = 800
dtc.attrs = attrs

neuron = None

modelrs = ReducedModel(path_params['model_path'],name = str('regular_spiking'),backend =('NEURON',{'DTC':dtc}))

params = {'injected_square_current':
            {'amplitude': 20.0*pq.pA, 'delay':DELAY, 'duration':DURATION}}

modelrs.inject_square_current(params)
n_spikes = modelrs.get_spike_count()
print(n_spikes)
vmrs = modelrs.get_membrane_potential()
# Out:
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=3e-06 b=-0.0002 c=-50 d=0.01 C=0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.02}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=3e-06 b=-0.0002 c=-50 d=0.01 C=0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=800 amplitude=0.02}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=3e-06 b=-0.0002 c=-50 d=0.01 C=0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=800 amplitude=0.02}
# }
# 2

# %%
#              C    k     vr  vt vpeak   a      b   c    d  celltype
# ('RS',     (100, 0.7,  -60, -40, 35, 0.03,   -2, -50,  100,  1)),

attrs = {}
attrs['c'] = -50
attrs['vr'] = -60
attrs['vt'] = -40
attrs['vpeak'] = 35

#hof[0].dtc.attrs
#Out[6]: {'a': 0.0001100000055, 'b': 30.0, 'vr': -40.0}
attrs['C'] = -100*10**-4
attrs['k'] = 0.7E-4
attrs['a'] = 0.0001100000055
attrs['b'] = -30.0*10**-4
attrs['d'] = 100E-4

dtc.attrs = attrs



DELAY = 100 
DURATION = 800
neuron = None

modelp = ReducedModel(path_params['model_path'],name = str('regular_spiking'),backend =('NEURON',{'DTC':dtc}))
observations = {}
predictions = {}

scores = {}
import dask.bag as db
for t in tests:
    LEMS_MODEL_PATH = path_params['model_path']
    model = ReducedModel(LEMS_MODEL_PATH,name=str('vanilla'),backend='NEURON')
    model.set_attrs(dtc.attrs)
    score = t.judge(model)
    scores[str(t)] = score
    observations[str(t)] = score.observation
    print(dir(score))
    #if hasattr(score,'prediction'):
    predictions[str(t)] = score.prediction
# Out:
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# RS_pop[0] { nseg=1  L=10  Ra=35.4
#
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# RS_pop[0] { nseg=1  L=10  Ra=35.4
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# 	/*location 0 attached to cell 0*/
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# 	/*location 0 attached to cell 0*/
#
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
#
# 	/* First segment only */
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# 	insert morphology { diam=10}
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# 	/*location 0 attached to cell 0*/
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# 	/* First segment only */
# 	/* First segment only */
# 	insert capacitance { cm=31.831}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# 	insert capacitance { cm=31.831}
#
# 	insert morphology { diam=10}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert morphology { diam=10}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert capacitance { cm=31.831}
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# 	/*location 0 attached to cell 0*/
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.166667}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# }
# 	/* First segment only */
# 	/*location 0 attached to cell 0*/
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0}
# 	insert capacitance { cm=31.831}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.25}
# 	insert morphology { diam=10}
# 	/* First segment only */
# }
# 	/*location 0 attached to cell 0*/
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# }
# 	/* First segment only */
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert capacitance { cm=31.831}
# 	insert capacitance { cm=31.831}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.0833333}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# }
# 	insert capacitance { cm=31.831}
# 	/* First segment only */
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.208333}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.125}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# }
# 	/* First segment only */
# 	/*location 0 attached to cell 0*/
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.166667}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.0416667}
# 	insert morphology { diam=10}
# 	/* First segment only */
# 	/*location 0 attached to cell 0*/
# }
# }
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# 	/*location 0 attached to cell 0*/
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# 	insert capacitance { cm=31.831}
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0}
# 	/* First segment only */
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.0833333}
# 	insert capacitance { cm=31.831}
# 	insert morphology { diam=10}
# }
# 	insert morphology { diam=10}
# }
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.25}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
# 	insert capacitance { cm=31.831}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.166667}
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.208333}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	/*location 0 attached to cell 0*/
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.0416667}
# }
# 	/*location 0 attached to cell 0*/
# 	/*location 0 attached to cell 0*/
# }
# 	/* First segment only */
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.125}
# }
# 	/* First segment only */
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert morphology { diam=10}
# }
# 	/* First segment only */
# 	/*location 0 attached to cell 0*/
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert capacitance { cm=31.831}
# 	/*location 0 attached to cell 0*/
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert morphology { diam=10}
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
# 	insert capacitance { cm=31.831}
# 	/* First segment only */
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
# 	insert morphology { diam=10}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.0833333}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.25}
# 	insert capacitance { cm=31.831}
# }
# }
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.208333}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# }
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.0416667}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.125}
# }
# }
# }
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# RS_pop[0] { nseg=1  L=10  Ra=35.4
#
# 	/*location 0 attached to cell 0*/
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# 	/*location 0 attached to cell 0*/
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# 	/* First segment only */
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# 	/* First segment only */
# 	insert morphology { diam=10}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
#
# 	insert morphology { diam=10}
#
# 	/*location 0 attached to cell 0*/
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# 	insert capacitance { cm=31.831}
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# 	/* First segment only */
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
#
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.0104167}
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# }
# 	/*location 0 attached to cell 0*/
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.00520833}
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
# 	/*location 0 attached to cell 0*/
# }
# 	insert capacitance { cm=31.831}
# 	/* First segment only */
# 	/* First segment only */
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert morphology { diam=10}
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert morphology { diam=10}
# 	/* First segment only */
# 	insert capacitance { cm=31.831}
# 	insert capacitance { cm=31.831}
# 	/*location 0 attached to cell 0*/
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.015625}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
# 	insert morphology { diam=10}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.0208333}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.0364583}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.0208333}
# }
# }
# 	/* First segment only */
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.0104167}
# 	/*location 0 attached to cell 0*/
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# }
# 	insert morphology { diam=10}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.03125}
# 	/*location 0 attached to cell 0*/
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert capacitance { cm=31.831}
# 	/* First segment only */
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
# 	/* First segment only */
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	/*location 0 attached to cell 0*/
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.00520833}
# 	insert morphology { diam=10}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert capacitance { cm=31.831}
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# 	insert capacitance { cm=31.831}
# }
# 	insert morphology { diam=10}
# 	/* First segment only */
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	/* First segment only */
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.0364583}
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert capacitance { cm=31.831}
# }
# 	insert morphology { diam=10}
# 	/*location 0 attached to cell 0*/
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.0208333}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert capacitance { cm=31.831}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.0104167}
# 	/*location 0 attached to cell 0*/
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.0208333}
# 	insert morphology { diam=10}
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.015625}
# 	insert RS_Iext { weight=1 delay=0 duration=1000 amplitude=0.03125}
# 	insert capacitance { cm=31.831}
# }
# }
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
# }
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# }
# 	/*location 0 attached to cell 0*/
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/* First segment only */
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	/*location 0 attached to cell 0*/
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.00520833}
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert morphology { diam=10}
# }
# 	insert capacitance { cm=31.831}
# 	insert capacitance { cm=31.831}
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.0364583}
# 	insert capacitance { cm=31.831}
# }
# 	insert morphology { diam=10}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.03125}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.0208333}
# }
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert capacitance { cm=31.831}
# }
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.015625}
# 	insert RS_Iext { weight=1 delay=100 duration=1000 amplitude=0.0208333}
# }
# }
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_types', '_allowed_types_message', '_check_score', '_class', '_describe', '_description', '_id', '_properties', '_raw', '_state', '_url', 'check_score', 'color', 'compute', 'describe', 'describe_from_docstring', 'description', 'dict_hash', 'extract_mean_or_value', 'extract_means_or_values', 'get_raw', 'get_remote', 'get_remote_url', 'get_repo', 'get_version', 'hash', 'id', 'json', 'model', 'observation', 'plot_vm', 'prediction', 'properties', 'raw', 'raw_props', 'related_data', 'remote_url', 'score', 'score_type', 'set_raw', 'sort_key', 'state', 'summarize', 'summary', 'test', 'unpicklable', 'url', 'value_color', 'version']
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=-0.01}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=300 amplitude=-0.01}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=300 amplitude=-0.01}
# }
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_types', '_allowed_types_message', '_check_score', '_class', '_describe', '_description', '_id', '_properties', '_raw', '_state', '_url', 'check_score', 'color', 'compute', 'describe', 'describe_from_docstring', 'description', 'dict_hash', 'extract_mean_or_value', 'extract_means_or_values', 'get_raw', 'get_remote', 'get_remote_url', 'get_repo', 'get_version', 'hash', 'id', 'json', 'model', 'observation', 'plot_vm', 'prediction', 'properties', 'raw', 'raw_props', 'related_data', 'remote_url', 'score', 'score_type', 'set_raw', 'sort_key', 'state', 'summarize', 'summary', 'test', 'unpicklable', 'url', 'value_color', 'version']
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=-0.01}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=100 amplitude=-0.01}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=100 amplitude=-0.01}
# }
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_types', '_allowed_types_message', '_check_score', '_class', '_describe', '_description', '_id', '_properties', '_raw', '_state', '_url', 'check_score', 'color', 'compute', 'describe', 'describe_from_docstring', 'description', 'dict_hash', 'extract_mean_or_value', 'extract_means_or_values', 'get_raw', 'get_remote', 'get_remote_url', 'get_repo', 'get_version', 'hash', 'id', 'json', 'model', 'observation', 'plot_vm', 'prediction', 'properties', 'raw', 'raw_props', 'related_data', 'remote_url', 'score', 'score_type', 'set_raw', 'sort_key', 'state', 'summarize', 'summary', 'test', 'unpicklable', 'url', 'value_color', 'version']
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=-0.01}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=100 amplitude=-0.01}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=100 amplitude=-0.01}
# }
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_types', '_allowed_types_message', '_check_score', '_class', '_describe', '_description', '_id', '_properties', '_raw', '_state', '_url', 'check_score', 'color', 'compute', 'describe', 'describe_from_docstring', 'description', 'dict_hash', 'extract_mean_or_value', 'extract_means_or_values', 'get_raw', 'get_remote', 'get_remote_url', 'get_repo', 'get_version', 'hash', 'id', 'json', 'model', 'observation', 'plot_vm', 'prediction', 'properties', 'raw', 'raw_props', 'related_data', 'remote_url', 'score', 'score_type', 'set_raw', 'sort_key', 'state', 'summarize', 'summary', 'test', 'unpicklable', 'url', 'value_color', 'version']
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=300 amplitude=0}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=300 amplitude=0}
# }
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_types', '_allowed_types_message', '_check_score', '_class', '_describe', '_description', '_id', '_properties', '_raw', '_state', '_url', 'check_score', 'color', 'compute', 'describe', 'describe_from_docstring', 'description', 'dict_hash', 'extract_mean_or_value', 'extract_means_or_values', 'get_raw', 'get_remote', 'get_remote_url', 'get_repo', 'get_version', 'hash', 'id', 'json', 'model', 'observation', 'plot_vm', 'prediction', 'properties', 'raw', 'raw_props', 'related_data', 'remote_url', 'score', 'score_type', 'set_raw', 'sort_key', 'state', 'summarize', 'summary', 'test', 'unpicklable', 'url', 'value_color', 'version']
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.1}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=300 amplitude=0.1}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=300 amplitude=0.1}
# }
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_types', '_allowed_types_message', '_check_score', '_class', '_describe', '_description', '_id', '_properties', '_raw', '_state', '_url', 'check_score', 'color', 'compute', 'describe', 'describe_from_docstring', 'description', 'dict_hash', 'extract_mean_or_value', 'extract_means_or_values', 'get_raw', 'get_remote', 'get_remote_url', 'get_repo', 'get_version', 'hash', 'id', 'json', 'model', 'observation', 'plot_vm', 'prediction', 'properties', 'raw', 'raw_props', 'related_data', 'remote_url', 'score', 'score_type', 'set_raw', 'sort_key', 'state', 'summarize', 'summary', 'test', 'unpicklable', 'url', 'value_color', 'version']
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.1}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=300 amplitude=0.1}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=300 amplitude=0.1}
# }
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_types', '_allowed_types_message', '_check_score', '_class', '_describe', '_description', '_id', '_properties', '_raw', '_state', '_url', 'check_score', 'color', 'compute', 'describe', 'describe_from_docstring', 'description', 'dict_hash', 'extract_mean_or_value', 'extract_means_or_values', 'get_raw', 'get_remote', 'get_remote_url', 'get_repo', 'get_version', 'hash', 'id', 'json', 'model', 'observation', 'plot_vm', 'prediction', 'properties', 'raw', 'raw_props', 'related_data', 'remote_url', 'score', 'score_type', 'set_raw', 'sort_key', 'state', 'summarize', 'summary', 'test', 'unpicklable', 'url', 'value_color', 'version']
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.1}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=300 amplitude=0.1}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=0.00011 b=-0.003 c=-50 d=0.01 C=-0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=300 amplitude=0.1}
# }
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_types', '_allowed_types_message', '_check_score', '_class', '_describe', '_description', '_id', '_properties', '_raw', '_state', '_url', 'check_score', 'color', 'compute', 'describe', 'describe_from_docstring', 'description', 'dict_hash', 'extract_mean_or_value', 'extract_means_or_values', 'get_raw', 'get_remote', 'get_remote_url', 'get_repo', 'get_version', 'hash', 'id', 'json', 'model', 'observation', 'plot_vm', 'prediction', 'properties', 'raw', 'raw_props', 'related_data', 'remote_url', 'score', 'score_type', 'set_raw', 'sort_key', 'state', 'summarize', 'summary', 'test', 'unpicklable', 'url', 'value_color', 'version']

# %%
#print(observations)
#print(predictions)
simple_pa = { k:v['value'] for k,v in predictions.items() if 'value' in v.keys() }
simple_pa.update({ k:v['mean'] for k,v in predictions.items() if 'mean' in v.keys() })
simple_p = { k:v for k,v in simple_pa.items() if 'AP' in k or 'RestingPotentialTest' in k}



simple_obsa = { k:v['value'] for k,v in observations.items() if 'value' in v.keys() }
simple_obsa.update({ k:v['mean'] for k,v in observations.items() if 'mean' in v.keys() })
simple_obs = { k:v for k,v in simple_obsa.items() if 'AP' in k or 'RestingPotentialTest' in k }


deltas = {k:simple_p[k]-v for k,v in simple_obs.items() }
print(deltas)
import seaborn as sns


    
import matplotlib.pyplot as plt
def plot_lines(vm,plt,obs,pred,deltas,model,rh):
    params = {'injected_square_current':
                {'amplitude': rh*pq.pA, 'delay':DELAY, 'duration':DURATION}}

    model.inject_square_current(params)
    vm = model.get_membrane_potential()


    #vm = model.get_membrane_potential()
    times = vm.times
    st = model.get_spike_train()
    if len(st) > 1:
        st = st[0]
        
    for k,v in pred.items():
        if 'InjectedCurrentAPWidthTest' not in k:
            p = [float(pred[k]) for i in times]
            o = [float(obs[k]) for i in times]
            #plt.fill(x, Y, facecolor='blue', alpha=0.5)
            #plt.fill_between(o, p, times)#, alpha=0.5)
            plt.plot(times,p,label = str('prediction ')+str(k))
            plt.plot(times,o,label = str('observation ')+str(k))
        else:
            intervalp = pred[k]
            newti = []
            for i in times:
                if i < st:
                    newti.append(pred['InjectedCurrentAPThresholdTest'])

                if i >= st and i <= intervalp*10000.0 + st:    
                    newti.append(pred['InjectedCurrentAPAmplitudeTest'])
                
                if i > intervalp*10000.0 + st:
                    newti.append(pred['InjectedCurrentAPThresholdTest'])
                    
                #print(len(times),len(newti))        
            plt.plot(times,newti,label='spike width')


        
        plt.plot(times,vm)

    plt.xlabel('ms')
    plt.ylabel('mV')
    plt.legend(loc=2, fontsize = 'x-small')
    #plt.legend()
    #plt
    return plt
vm = model.get_membrane_potential()
rh = simple_pa['RheobaseTestP'] 
plot_lines(vm, plt, simple_obs, simple_p, deltas, model,rh)
# Out:
# {'RestingPotentialTest': array(-59.94207093026352) * V, 'InjectedCurrentAPWidthTest': array(0.0034950000000000003) * s, 'InjectedCurrentAPAmplitudeTest': array(-0.04780792320671433) * V, 'InjectedCurrentAPThresholdTest': array(0.03673935623478438) * V}
# Mechanisms already loaded from path: /home/jovyan/neuronunit/neuronunit/models/NeuroML2.  Aborting.
#
#     Starting simulation in NEURON of 650.0ms generated from NeuroML2 model...
#
# Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=3e-06 b=-0.0002 c=-50 d=0.01 C=0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=520 amplitude=0.0104167}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=3e-06 b=-0.0002 c=-50 d=0.01 C=0.01}
# 	insert RS_Iext { weight=1 delay=0 duration=800 amplitude=0.0104167}
# }
# RS_pop[0] { nseg=1  L=10  Ra=35.4
# 	/*location 0 attached to cell 0*/
# 	/* First segment only */
# 	insert morphology { diam=10}
# 	insert capacitance { cm=31.831}
# 	insert RS { v0=-60 k=7e-05 vr=-60 vt=-40 vpeak=35 a=3e-06 b=-0.0002 c=-50 d=0.01 C=0.01}
# 	insert RS_Iext { weight=1 delay=100 duration=800 amplitude=0.0104167}
# }
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
sort_scores = {k:1.0-v.sort_key for k,v in scores.items() }

# %%
import pandas as pd
import seaborn as sns
dfs = pd.DataFrame.from_dict(pd.Series(sort_scores), orient='columns')

dfg = dfs.reset_index(drop=True)

# Set colormap equal to seaborns light green color palette
cm = sns.light_palette("green", as_cmap=True)
display(dfg.style.background_gradient(cmap=cm))
# Out:
#         <style  type="text/css" >
#
#
#             #T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow0_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow1_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow2_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow3_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow4_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow5_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow6_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow7_col0 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#         </style>
#
#         <table id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   0
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow0_col0"
#                  class="data row0 col0" >
#                     1
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow1_col0"
#                  class="data row1 col0" >
#                     0.999823
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow2_col0"
#                  class="data row2 col0" >
#                     1
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow3_col0"
#                  class="data row3 col0" >
#                     1
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow4_col0"
#                  class="data row4 col0" >
#                     1
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow5_col0"
#                  class="data row5 col0" >
#                     1
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e"
#                  class="row_heading level0 row6" rowspan=1>
#                     6
#
#
#
#                 <td id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow6_col0"
#                  class="data row6 col0" >
#                     0.999304
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2e"
#                  class="row_heading level0 row7" rowspan=1>
#                     7
#
#
#
#                 <td id="T_eabcd57c_9cd9_11e8_afb0_bfc7a5272f2erow7_col0"
#                  class="data row7 col0" >
#                     0.674414
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
plt = plot(vmrs2,plt)
plt.show()

# %% [markdown]
# Chattering

# %%
plt.clf()
plt = plot(vmrs,plt)
plt.show()

# %%
#C = 50     vr = -60     vt = -40     k = 1.5    
#a = 0.03     b = 1     c = -40     d = 150     vPeak = 35  

attrs['vr'] = -60
attrs['vt'] = -40
attrs['c'] = -40
attrs['vpeak'] = 35




attrs['C'] = 50E-4
attrs['k'] = 1.5E-4
attrs['a'] = 0.03E-4
attrs['b'] = 1E-4
attrs['d'] = 150E-4




modelch = ReducedModel(path_params['model_path'],name = str('chattering'),backend =('NEURON',{'DTC':dtc}))

params = {'injected_square_current':
            {'amplitude': 300*pq.pA, 'delay':DELAY, 'duration':DURATION}}

modelch.inject_square_current(params)
n_spikes = modelch.get_spike_count()
vmch = modelch.get_membrane_potential()
print(n_spikes)

plt = plot(vmch,plt)
plt.show()

# %%
'''

x                       % time step  [ms]
 
http://www.physics.usyd.edu.au/teach_res/mp/ns/doc/nsIzhikevich3.htm
https://www.izhikevich.org/publications/izhikevich.m-
a=pars(1,1);
b=pars(1,2);
c=pars(1,3);
d=pars(1,4);
I=pars(1,5);
   


figNumber = figure(1);
clf;
set(figNumber,'NumberTitle','off','doublebuffer','on',...
        'Name','Simple Model by Izhikevich (2003)',...
        'Units','normalized','toolbar','figure',...
        'Position',[0.05 0.1 0.9 0.8]);
h1=subplot(4,2,1);
set(h1,'Position',[0.05 0.75 0.27 0.2])
vtrace=line('color','k','LineStyle','-','erase','background','xdata',[],'ydata',[],'zdata',[]);
axis([0 100 -100 30])
title('membrane potential, v')
xlabel('time (ms)');
'''
